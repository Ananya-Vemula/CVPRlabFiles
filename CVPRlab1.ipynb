# %% [markdown]
# LAB:01

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img=cv.imread('/content/7d2ad3c1eb2d88ef8092755eaba23e7a.jpg')
px=img[100,100]
print(img[25,25])
print(px)

print(img.shape)
print(img.size)
print(img.dtype)


bow=img[250:300,400:450]
img[100:150,450:500]=bow

cv2_imshow(img)
# Out:
# [135 161 167]
# [180 191 205]
# (429, 543, 3)
# 698841
# uint8
# <PIL.Image.Image image mode=RGB size=543x429>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

RED = [255,0,0]

img1 = cv.imread('/content/7d2ad3c1eb2d88ef8092755eaba23e7a.jpg')
assert img1 is not None, "file could not be read, check with os.path.exists()"

replicate = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT_101)
wrap = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_WRAP)
constant= cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_CONSTANT,value=RED)

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()

# %%
cp_1 = cv.imread('/content/cp_1.jpg')
cp_2 = cv.imread('/content/7d2ad3c1eb2d88ef8092755eaba23e7a.jpg')
assert cp_1 is not None, "file could not be read, check with os.path.exists()"
assert cp_2 is not None, "file could not be read, check with os.path.exists()"

# %%
print(cp_1.shape)
print(cp_2.shape)
# Out:
# (474, 474, 3)
# (429, 543, 3)

# %%
WHITE = [255,0,255]
img2new = cv.copyMakeBorder(cp_2,36,36,0,0,cv.BORDER_CONSTANT,value=WHITE)
cv2_imshow(img2new)
# Out:
# <PIL.Image.Image image mode=RGB size=544x430>
# <PIL.Image.Image image mode=RGB size=666x748>

# %%
# prompt: reshape cp_1 and cp_2 into the same size

# Resize cp_2 to match cp_1's dimensions
resized_cp_2 = cv.resize(cp_2, (cp_1.shape[1], cp_1.shape[0]))

print(cp_1.shape)
resized_cp_2.shape

#Now cp_1 and resized_cp_2 have the same dimensions
# Out:
# (474, 474, 3)
# (474, 474, 3)

# %%
dst = cv.addWeighted(cp_1,0.5,resized_cp_2,0.5,0) # Use resized_cp_2 instead of cp_2
cv2_imshow(dst)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=474x474>
